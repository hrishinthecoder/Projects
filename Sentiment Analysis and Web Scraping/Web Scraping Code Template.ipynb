# %%
# !pip install app_store_scraper
# Out:
# Collecting app_store_scraper
#   Downloading app_store_scraper-0.3.5-py3-none-any.whl (8.3 kB)
# Collecting requests==2.23.0 (from app_store_scraper)
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 2.0 MB/s eta 0:00:00
# Collecting chardet<4,>=3.0.2 (from requests==2.23.0->app_store_scraper)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.9 MB/s eta 0:00:00
# Collecting idna<3,>=2.5 (from requests==2.23.0->app_store_scraper)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.0 MB/s eta 0:00:00
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests==2.23.0->app_store_scraper)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (2024.2.2)
# Installing collected packages: chardet, urllib3, idna, requests, app_store_scraper
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.26.0 requires requests>=2.27.1, but you have requests 2.23.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.23.0 which is incompatible.
# tweepy 4.14.0 requires requests<3,>=2.27.0, but you have requests 2.23.0 which is incompatible.
# yfinance 0.2.37 requires requests>=2.31, but you have requests 2.23.0 which is incompatible.
# Successfully installed app_store_scraper-0.3.5 chardet-3.0.4 idna-2.10 requests-2.23.0 urllib3-1.25.11

# %%
from google_play_scrper import app,Sort,reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %%
a_df = pd.DataFrame(np.array(a_reviews.reviews),columns=['review'])
a_df2 = a_df.join(pd.DataFrame(a_df.pop('review').tolist()))

a_df2.drop(columns={'isEdited'},inplace = True)
a_df2.insert(loc=0, column='source', value='App Store')
a_df2['developer_response_date'] = None
a_df2['thumbs_up'] = None
a_df2['laguage_code'] = 'en'
a_df2['country_code'] = 'us'
a_df2.insert(loc=1, column='review_id', value=[uuid.uuid4() for _ in range(len(a_df2.index))])
a_df2.rename(columns= {'review': 'review_description','userName': 'user_name', 'date': 'review_date','title': 'review_title', 'developerResponse': 'developer_response'},inplace = True)
a_df2 = a_df2.where(pd.notnull(a_df2), None)

# %%
a_df2.shape
# Out:
# (690, 12)

# %%
from google_play_scraper import app, Sort, reviews_all

g_reviews = reviews_all(
        "com.microsoft.copilot",
        sleep_milliseconds=0, # defaults to 0
        lang='en', # defaults to 'en'
        country='us', # defaults to 'us'
         # defaults to Sort.MOST_RELEVANT
    )

# %%
g_df = pd.DataFrame(np.array(g_reviews),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))

g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent': 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'us'

# %%
g_df2.shape
# Out:
# (398, 13)

# %%
google=g_df2[g_df2['review_date'] > '2024-01-01']

# %%
google.shape
# Out:
# (398, 13)

# %%
google[google['review_date'] > '2024-01-01'].head()
# Out:
#         source                             review_id      user_name  \
# 0  Google Play  c6372e44-6661-4e4c-8f25-512f92e74b0c  Lilac Remodel
# 1  Google Play  b2b5b4ba-bf38-4894-a174-28d19af5afad  Kaitlyn Locke
# 2  Google Play  b5892077-c5b8-4092-b58a-255276e0624c    Jeremy Amos
# 3  Google Play  cab5b66a-b536-452f-95c7-dbb1843e90a2   Paul Roberts
# 4  Google Play  9ac10851-a205-4fa8-90fb-dd9af3f1ca31   Dennis Sulit
#
#   review_title                                 review_description  rating  \
# 0         None     want it to be more capable of app integration.       4
# 1         None  Copilot is a great tool for research use. It c...       3
# 2         None                             Thank you Microsoft 🙏🏼       5
# 3         None                                          fabulous!       5
# 4         None                                                wow       5
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0          0 2024-03-23 16:55:01               None                    None
# 1          1 2024-03-23 16:17:50               None                    None
# 2          0 2024-03-23 16:13:58               None                    None
# 3          0 2024-03-23 16:03:03               None                    None
# 4          0 2024-03-23 15:39:50               None                    None
#
#        appVersion laguage_code country_code
# 0  28.0.420319014           en           us
# 1  28.0.420319014           en           us
# 2  28.0.420319014           en           us
# 3  27.9.420301046           en           us
# 4  27.9.420301046           en           us

# %%
apple = a_df2[a_df2['review_date'] > '2024-01-01']

# %%
apple.shape
# Out:
# (666, 12)

# %%
result = pd.concat([g_df2,a_df2])
result
# Out:
#           source                             review_id  \
# 0    Google Play  c6372e44-6661-4e4c-8f25-512f92e74b0c
# 1    Google Play  b2b5b4ba-bf38-4894-a174-28d19af5afad
# 2    Google Play  b5892077-c5b8-4092-b58a-255276e0624c
# 3    Google Play  cab5b66a-b536-452f-95c7-dbb1843e90a2
# 4    Google Play  9ac10851-a205-4fa8-90fb-dd9af3f1ca31
# ..           ...                                   ...
# 685    App Store  4b1be51a-7498-49ec-a5d7-704ef400bd52
# 686    App Store  0f325978-8331-4d7d-aa01-47d54f8380ea
# 687    App Store  4080f729-d459-4ba1-b0a9-731169b9baab
# 688    App Store  47056927-bccd-4070-931f-17933677e922
# 689    App Store  b38a35a2-236b-4786-b317-79dae544e47e
#
#                         user_name                     review_title  \
# 0                   Lilac Remodel                             None
# 1                   Kaitlyn Locke                             None
# 2                     Jeremy Amos                             None
# 3                    Paul Roberts                             None
# 4                    Dennis Sulit                             None
# ..                            ...                              ...
# 685               Mohamed Elashry                            UI/UX
# 686  jifndjghjdjdghdmfnfhdjjdjfnf  THE BEST AI APP I’VE EVER USED!
# 687                  Candles Burn                      Fast search
# 688                   Jon Vincent   Does not produce accurate data
# 689                 proudslpdwife         Flex my creative muscles
#
#                                     review_description  rating thumbs_up  \
# 0       want it to be more capable of app integration.       4         0
# 1    Copilot is a great tool for research use. It c...       3         1
# 2                               Thank you Microsoft 🙏🏼       5         0
# 3                                            fabulous!       5         0
# 4                                                  wow       5         0
# ..                                                 ...     ...       ...
# 685  the splash screen have a tool bar of bing app ...       3      None
# 686  YET THERE’S CHAT, GPT FOUR IMAGE GENERATION, S...       5      None
# 687  Can not wait for more good things about Copilo...       5      None
# 688  App is so useless it is unaware it even exists...       1      None
# 689  Copilot has been a great resource for giving a...       4      None
#
#             review_date developer_response developer_response_date  \
# 0   2024-03-23 16:55:01               None                    None
# 1   2024-03-23 16:17:50               None                    None
# 2   2024-03-23 16:13:58               None                    None
# 3   2024-03-23 16:03:03               None                    None
# 4   2024-03-23 15:39:50               None                    None
# ..                  ...                ...                     ...
# 685 2024-02-09 12:17:50               None                    None
# 686 2024-01-18 08:42:52               None                    None
# 687 2024-03-23 07:22:49               None                    None
# 688 2024-01-06 04:35:01               None                    None
# 689 2024-03-23 00:11:22               None                    None
#
#          appVersion laguage_code country_code
# 0    28.0.420319014           en           us
# 1    28.0.420319014           en           us
# 2    28.0.420319014           en           us
# 3    27.9.420301046           en           us
# 4    27.9.420301046           en           us
# ..              ...          ...          ...
# 685             NaN           en           us
# 686             NaN           en           us
# 687             NaN           en           us
# 688             NaN           en           us
# 689             NaN           en           us
#
# [1088 rows x 13 columns]

# %%
result.to_csv('microsoftcopilot.csv')

from google.colab import files
files.download('microsoftcopilot.csv')
