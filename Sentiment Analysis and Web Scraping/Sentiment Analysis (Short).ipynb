# %%
import pandas as pd


bing = pd.read_csv('/content/BingAI.csv')
davinci = pd.read_csv('/content/DAVINCI.csv')
chatgpt= pd.read_excel('/content/chatgpt.xlsx')
copilot = pd.read_excel('/content/copilot.xlsx')
gemini = pd.read_excel('/content/gemini.xlsx')

# %%
result = pd.concat([bing,davinci,chatgpt,copilot,gemini])
result.shape
# Out:
# (8568, 14)

# %%
# prompt: add a column in result which contains the name of file from which they are being concated

result['file_name'] = ['BingAI.csv'] * len(bing) + ['DAVINCI.csv'] * len(davinci) + ['chatgpt.xlsx'] * len(chatgpt) + ['copilot.xlsx'] * len(copilot) + ['gemini.xlsx'] * len(gemini)

# %%
result
# Out:
#      Unnamed: 0       source                             review_id  \
# 0             0  Google Play  d2676cae-da30-4e57-9a05-21ee5cd78495
# 1             1  Google Play  b313673d-5446-4479-acc0-5c780181d482
# 2             2  Google Play  9bce6943-4a9e-4fc1-a2f7-eef460fd1b1d
# 3             3  Google Play  eb57122a-2da6-4d25-8610-f211bf06fbe1
# 4             4  Google Play  c70e4556-b060-4538-bde3-6b272a18153c
# ..          ...          ...                                   ...
# 592         592  Google Play  1ad07775-c4c3-4b06-b524-a3bf9966b2a0
# 593         593  Google Play  1ae80c7c-a9ce-4275-952d-bd307f014a41
# 594         594  Google Play  75289a4a-1a95-4a6e-ac00-320a90bdd974
# 595         595  Google Play  662e9a1a-e5ba-44fb-934f-012386bb349c
# 596         596  Google Play  2288655b-eae3-472e-9f8b-19911c1de72c
#
#                  user_name review_title  \
# 0                 San Sann          NaN
# 1             connect2fact          NaN
# ...

# %%
result.head()
# Out:
#    Unnamed: 0       source                             review_id  \
# 0           0  Google Play  d2676cae-da30-4e57-9a05-21ee5cd78495
# 1           1  Google Play  b313673d-5446-4479-acc0-5c780181d482
# 2           2  Google Play  9bce6943-4a9e-4fc1-a2f7-eef460fd1b1d
# 3           3  Google Play  eb57122a-2da6-4d25-8610-f211bf06fbe1
# 4           4  Google Play  c70e4556-b060-4538-bde3-6b272a18153c
#
#          user_name review_title  \
# 0         San Sann          NaN
# 1     connect2fact          NaN
# 2      Parvez Khan          NaN
# 3  Shahida paracha          NaN
# 4     Tech Techiee          NaN
#
#                                   review_description  rating  thumbs_up  \
# 0  quite refreshing and impressive but not sure w...       3        0.0
# 1                                             nice 🙂       1        0.0
# 2                                                 ✌🏻       5        0.0
# 3            very good and intresting .i lov rashiya       5        0.0
# ...

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the sentiment lexicon file if necessary
nltk.download('vader_lexicon')

# Load the sentiment lexicon
lexicon_file = nltk.data.load('sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt')

# Create the SentimentIntensityAnalyzer object
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
google.shape
# Out:
# (597, 14)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
res = {}
for i,row in tqdm(chatgpt.iterrows(), total=len(chatgpt)):

    text= row['review_description']
    myid = row['review_id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/3495 [00:00<?, ?it/s]

# %%
com =pd.DataFrame(res).T
com.shape
# Out:
# (3495, 4)

# %%
com =pd.DataFrame(res).T
com = com.reset_index().rename(columns={'index':'review_id'})
com = com.merge(chatgpt, how='left')

# %%
com.head(4)
# Out:
#                               review_id    neg    neu    pos  compound  \
# 0  d86a3b48-fd34-4dce-be56-2fe7aa5f2012  0.123  0.778  0.099   -0.8576
# 1  49fc6afc-c4c4-4fc0-8485-29f717118da8  0.093  0.849  0.058   -0.5954
# 2  0c1e4d82-88e3-439c-8791-fb2e614604b7  0.019  0.868  0.113    0.9379
# 3  dfe4a45b-932b-4b26-84b4-124a809e538e  0.058  0.814  0.128    0.9288
#
#    Unnamed: 0 source user_name review_title review_description  rating  \
# 0         NaN    NaN       NaN          NaN                NaN     NaN
# 1         NaN    NaN       NaN          NaN                NaN     NaN
# 2         NaN    NaN       NaN          NaN                NaN     NaN
# 3         NaN    NaN       NaN          NaN                NaN     NaN
#
#    thumbs_up review_date  developer_response  developer_response_date  \
# 0        NaN         NaN                 NaN                      NaN
# 1        NaN         NaN                 NaN                      NaN
# ...

# %%
def categorize_reviews(rating):
  if rating <= 2:
     return "Negative Review"
  elif rating == 3:
     return "Neutral Review"
  else: return "Positive Review"

com['Reviews Category'] = com['rating'].apply(categorize_reviews)
com.head()
# Out:
#                               review_id    neg    neu    pos  compound  \
# 0  d86a3b48-fd34-4dce-be56-2fe7aa5f2012  0.123  0.778  0.099   -0.8576
# 1  49fc6afc-c4c4-4fc0-8485-29f717118da8  0.093  0.849  0.058   -0.5954
# 2  0c1e4d82-88e3-439c-8791-fb2e614604b7  0.019  0.868  0.113    0.9379
# 3  dfe4a45b-932b-4b26-84b4-124a809e538e  0.058  0.814  0.128    0.9288
# 4  5bbe6923-8181-446a-8b1c-d753a660f03b  0.046  0.881  0.073    0.7845
#
#    Unnamed: 0 source user_name review_title review_description  rating  \
# 0         NaN    NaN       NaN          NaN                NaN     NaN
# 1         NaN    NaN       NaN          NaN                NaN     NaN
# 2         NaN    NaN       NaN          NaN                NaN     NaN
# 3         NaN    NaN       NaN          NaN                NaN     NaN
# 4         NaN    NaN       NaN          NaN                NaN     NaN
#
#    thumbs_up review_date  developer_response  developer_response_date  \
# ...

# %%
nodp =com.drop_duplicates(subset='user_name', keep='first')

# %%
nodp.shape
# Out:
# (7736, 19)

# %%
nodp.head(4)
# Out:
#                               review_id    neg    neu    pos  compound  \
# 0  d86a3b48-fd34-4dce-be56-2fe7aa5f2012  0.123  0.778  0.099   -0.8576
#
#    Unnamed: 0 source user_name review_title review_description  rating  \
# 0         NaN    NaN       NaN          NaN                NaN     NaN
#
#    thumbs_up review_date  developer_response  developer_response_date  \
# 0        NaN         NaN                 NaN                      NaN
#
#   appVersion laguage_code country_code Reviews Category
# 0        NaN          NaN          NaN  Positive Review

# %%
nodp
# Out:
#                                  review_id    neg    neu    pos  compound  \
# 0     d2676cae-da30-4e57-9a05-21ee5cd78495  0.147  0.695  0.158   -0.0269
# 7176  c167861e-49f8-4c5b-879a-99d9da4789ce  0.128  0.872  0.000   -0.5233
# 7179  77238f3d-32ca-4a09-8fe0-811dac4156f7  0.000  0.795  0.205    0.6597
# 7181  b59b4a7a-83d7-4022-99f8-00e7ec5e4187  0.253  0.747  0.000   -0.7757
# 7184  110ad8c1-1560-4a18-bbb6-136efbdacd74  0.000  1.000  0.000    0.0000
# ...                                    ...    ...    ...    ...       ...
# 7761  7e5c3d39-0399-42a2-bd1c-a4ae1b82e27b  0.058  0.922  0.020   -0.4199
# 7762  74c734b1-54f3-413a-96e4-6790e7faae37  0.000  1.000  0.000    0.0000
# 7763  213baa13-47f0-4646-92d9-f44072377ba2  0.000  0.811  0.189    0.2732
# 7764  08c096f9-aafb-4b6e-bc81-941ad950eb9c  0.483  0.517  0.000   -0.4215
# 7768  1ad07775-c4c3-4b06-b524-a3bf9966b2a0  0.070  0.775  0.155    0.8383
#
#       Unnamed: 0       source                        user_name  review_title  \
# ...

# %%
nodp.head()
# Out:
#                               review_id    neg    neu    pos  compound  \
# 0  7264c271-febd-4b7a-b8d0-8b49c5d3f792  0.000  0.556  0.444    0.8860
# 1  d2676cae-da30-4e57-9a05-21ee5cd78495  0.147  0.695  0.158   -0.0269
# 2  b313673d-5446-4479-acc0-5c780181d482  0.000  0.000  1.000    0.4215
# 3  9bce6943-4a9e-4fc1-a2f7-eef460fd1b1d  0.000  1.000  0.000    0.0000
# 4  eb57122a-2da6-4d25-8610-f211bf06fbe1  0.000  0.653  0.347    0.4927
#
#    Unnamed: 0       source        user_name review_title  \
# 0           0  Google Play   Effort Forever          NaN
# 1           1  Google Play         San Sann          NaN
# 2           2  Google Play     connect2fact          NaN
# 3           3  Google Play      Parvez Khan          NaN
# 4           4  Google Play  Shahida paracha          NaN
#
#                                   review_description  rating  thumbs_up  \
# 0  Love this App use it for Our channel on YouTub...       5        0.0
# ...

# %%
# prompt: download nodp as a csv file

nodp.to_csv('raw.csv', index=False)

# Download the file from Google Drive
files.download('raw.csv')

# %%
nodp[nodp['rating']==3].shape
# Out:
# (48, 19)

# %%
nodp[nodp['rating']<3].shape
# Out:
# (316, 19)

# %%
nodp[nodp['rating']>3].shape
# Out:
# (231, 19)

# %%
# prompt: find me the mean of pos in nodp

print(nodp['pos'].mean())
# Out:
# 0.20869579831932775

# %%
# prompt: find me the mean of pos in nodp

print(nodp['neg'].mean())
# Out:
# 0.07653781512605043

# %%
# prompt: find me the mean of pos in nodp

print(nodp['neu'].mean())
# Out:
# 0.7130873949579832

# %%
# prompt: find me the mean of pos in nodp

print(com['compound'].mean())
# Out:
# 0.3798964806866953

# %%
import pandas as pd
m = pd.read_csv('/content/All Data.csv')

# %%
m.head()
# Out:
#    Unnamed: 0.1                             review_id  Satisfaction  \
# 0             0  d2676cae-da30-4e57-9a05-21ee5cd78495         0.147
# 1             2  b313673d-5446-4479-acc0-5c780181d482         0.000
# 2             4  9bce6943-4a9e-4fc1-a2f7-eef460fd1b1d         1.000
# 3             6  eb57122a-2da6-4d25-8610-f211bf06fbe1         0.000
# 4             8  c70e4556-b060-4538-bde3-6b272a18153c         0.147
#
#    Effectiveness  Efficiency  compound  Unnamed: 0       source  \
# 0          0.695       0.158   -0.0269           0  Google Play
# 1          0.000       1.000    0.4215           1  Google Play
# 2          1.000       0.000    0.0000           2  Google Play
# 3          0.653       0.347    0.4927           3  Google Play
# 4          0.720       0.133   -0.1280           4  Google Play
#
#          user_name review_title  \
# 0         San Sann          NaN
# 1     connect2fact          NaN
# 2      Parvez Khan          NaN
# 3  Shahida paracha          NaN
# ...
